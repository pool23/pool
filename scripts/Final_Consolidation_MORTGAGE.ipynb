# %%
import glob
import os
import pandas as pd
import numpy as np
import datetime
import warnings
from maks_lib import output_path
from maks_lib import input_path
warnings.simplefilter(action='ignore')
now = datetime.datetime.now()

extension = 'csv'

# %%
all_files = glob.glob(output_path+'*.{}'.format(extension))
all_mortage_files  = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and "Mortgage" in file.split("\\")[-1]]
all_deposite_files = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and file not in all_mortage_files]

# %%
COLUMN_NAMES = list(pd.read_csv(all_mortage_files[0]).columns)
df_mortgage = pd.DataFrame(columns=COLUMN_NAMES) 
df_deposit = pd.DataFrame(columns=COLUMN_NAMES)

# %%
df_mortgage
# Out:
# Empty DataFrame
# Columns: [Date, Bank_Name, Bank_Product, Bank_Product_Type, Bank_Offer_Feature, Bank_Product_Name, Product_Term, Balance, Product_Interest, Product_Apy, Mortgage_Down_Payment, Mortgage_Loan, Min_Credit_Score_Mortagage, Mortgage_Apr]
# Index: []

# %%
for idx, file in enumerate(all_mortage_files):
    print(file)
    print(pd.read_csv(all_mortage_files[idx]).shape[1])
# Out:
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consalidate_SunTrust_Data_Mortgage_08_03_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_ALLY_Data_Mortgage_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_BOA_Data_Mortgage03_08_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_CITI_Data_Mortgage_03_08_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_JPMorgan_Data_Mortgage.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_PNC_Data_Mortgage_03_08_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_WellsF_Data_Mortgage_03_08_2018.csv
# 14

# %%
count = 1
for file in all_mortage_files:
    df_temp =pd.read_csv(file)
    df_temp.columns = ['Date', 'Bank_Name', 'Bank_Product', 'Bank_Product_Type',
       'Bank_Offer_Feature', 'Bank_Product_Name', 'Product_Term', 'Balance',
       'Product_Interest', 'Product_Apy', 'Mortgage_Down_Payment',
       'Mortgage_Loan', 'Min_Credit_Score_Mortagage', 'Mortgage_Apr']
    df_mortgage = pd.concat([df_mortgage, df_temp])

# %%
df_mortgage.shape
# Out:
# (152, 14)

# %%
df_mortgage
# Out:
#           Date           Bank_Name Bank_Product Bank_Product_Type  \
# 0     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 1     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 2     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 3     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 4     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 5     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 6     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 7     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 8     3-Aug-18  SUNTRUST BANKS INC     Mortgage               NaN
# 0   03-09-2018                ALLY     Mortgage               NaN
# 1   03-09-2018                ALLY     Mortgage               NaN
# 2   03-09-2018                ALLY     Mortgage               NaN
# 3   03-09-2018                ALLY     Mortgage               NaN
# 4   03-09-2018                ALLY     Mortgage               NaN
# 5   03-09-2018                ALLY     Mortgage               NaN
# 6   03-09-2018                ALLY     Mortgage               NaN
# 7   03-09-2018                ALLY     Mortgage               NaN
# 8   03-09-2018                ALLY     Mortgage               NaN
# 9   03-09-2018                ALLY     Mortgage               NaN
# 10  03-09-2018                ALLY     Mortgage               NaN
# 11  03-09-2018                ALLY     Mortgage               NaN
# 12  03-09-2018                ALLY     Mortgage               NaN
# 13  03-09-2018                ALLY     Mortgage               NaN
# 14  03-09-2018                ALLY     Mortgage               NaN
# 15  03-09-2018                ALLY     Mortgage               NaN
# 16  03-09-2018                ALLY     Mortgage               NaN
# 17  03-09-2018                ALLY     Mortgage               NaN
# 18  03-09-2018                ALLY     Mortgage               NaN
# 19  03-09-2018                ALLY     Mortgage               NaN
# 20  03-09-2018                ALLY     Mortgage               NaN
# ..         ...                 ...          ...               ...
# 23  03-08-2018                 PNC     Mortgage          Mortgage
# 24  03-08-2018                 PNC     Mortgage          Mortgage
# 25  03-08-2018                 PNC     Mortgage          Mortgage
# 26  03-08-2018                 PNC     Mortgage          Mortgage
# 27  03-08-2018                 PNC     Mortgage          Mortgage
# 28  03-08-2018                 PNC     Mortgage          Mortgage
# 29  03-08-2018                 PNC     Mortgage          Mortgage
# 30  03-08-2018                 PNC     Mortgage          Mortgage
# 31  03-08-2018                 PNC     Mortgage          Mortgage
# 32  03-08-2018                 PNC     Mortgage          Mortgage
# 0     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 1     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 2     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 3     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 4     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 5     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 6     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 7     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 8     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 9     03-08-18         WELLS FARGO     Mortgage          Mortgage
# 10    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 11    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 12    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 13    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 14    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 15    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 16    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 17    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 18    03-08-18         WELLS FARGO     Mortgage          Mortgage
# 19    03-08-18         WELLS FARGO     Mortgage          Mortgage
#
#    Bank_Offer_Feature                Bank_Product_Name Product_Term Balance  \
# 0             Offline             Agency 30 Year Fixed      30 year     NaN
# 1             Offline             Agency 15 Year Fixed      15 year     NaN
# 2             Offline              Jumbo 30 Year Fixed      30 year     NaN
# 3             Offline           Agency 30 Year 5/1 ARM      30 year     NaN
# 4             Offline           Agency 30 Year 7/1 ARM      30 year     NaN
# 5             Offline                FHA 30 Year Fixed      30 year     NaN
# 6             Offline                 VA 30 Year Fixed      30 year     NaN
# 7             Offline                 VA 15 Year Fixed      15 year     NaN
# 8             Offline               VA 30 Year 5/1 ARM      30 year     NaN
# 0              Online      Fixed Rate Mortgage _ 30-yr   360 Months     NaN
# 1              Online      Fixed Rate Mortgage _ 30-yr   360 Months     NaN
# 2              Online      Fixed Rate Mortgage _ 30-yr   360 Months     NaN
# 3              Online      Fixed Rate Mortgage _ 25-yr   300 Months     NaN
# 4              Online      Fixed Rate Mortgage _ 25-yr   300 Months     NaN
# 5              Online      Fixed Rate Mortgage _ 25-yr   300 Months     NaN
# 6              Online      Fixed Rate Mortgage _ 20-yr   240 Months     NaN
# 7              Online      Fixed Rate Mortgage _ 20-yr   240 Months     NaN
# 8              Online      Fixed Rate Mortgage _ 20-yr   240 Months     NaN
# 9              Online      Fixed Rate Mortgage _ 15-yr   180 Months     NaN
# 10             Online      Fixed Rate Mortgage _ 15-yr   180 Months     NaN
# 11             Online      Fixed Rate Mortgage _ 15-yr   180 Months     NaN
# 12             Online      Fixed Rate Mortgage _ 10-yr   120 Months     NaN
# 13             Online      Fixed Rate Mortgage _ 10-yr   120 Months     NaN
# 14             Online      Fixed Rate Mortgage _ 10-yr   120 Months     NaN
# 15             Online  Adjustable Rate Mortgage _ 10/1   360 Months     NaN
# 16             Online  Adjustable Rate Mortgage _ 10/1   360 Months     NaN
# 17             Online  Adjustable Rate Mortgage _ 10/1   360 Months     NaN
# 18             Online  Adjustable Rate Mortgage _ 10/1   360 Months     NaN
# 19             Online  Adjustable Rate Mortgage _ 10/1   360 Months     NaN
# 20             Online  Adjustable Rate Mortgage _ 10/1   360 Months     NaN
# ..                ...                              ...          ...     ...
# 23            offline                   VA 15 Yr Fixed          NaN     NaN
# 24            offline          30 YR FIXEDLoan Details          NaN     NaN
# 25            offline          15 YR FIXEDLoan Details          NaN     NaN
# 26            offline           5-1 YR ARMLoan Details          NaN     NaN
# 27            offline           7-1 YR ARMLoan Details          NaN     NaN
# 28            offline          10-1 YR ARMLoan Details          NaN     NaN
# 29            offline                  FHA 30 YR FIXED          NaN     NaN
# 30            offline                      FHA 5-1 ARM          NaN     NaN
# 31            offline                   VA 30 YR FIXED          NaN     NaN
# 32            offline                       VA 5-1 ARM          NaN     NaN
# 0             offline               30-Year Fixed Rate      30 yrs      NaN
# 1             offline            30-Year Fixed-Rate VA      30 yrs      NaN
# 2             offline               20-Year Fixed Rate      20 yrs      NaN
# 3             offline               15-Year Fixed Rate      15 yrs      NaN
# 4             offline                          7/1 ARM      30 yrs      NaN
# 5             offline                          5/1 ARM      30 yrs      NaN
# 6             offline         30-Year Fixed-Rate Jumbo      30 yrs      NaN
# 7             offline         15-Year Fixed-Rate Jumbo      15 yrs      NaN
# 8             offline                    7/1 ARM Jumbo      30 yrs      NaN
# 9             offline                   10/1 ARM Jumbo      30 yrs      NaN
# 10            offline               30-Year Fixed Rate      30 yrs      NaN
# 11            offline            30-Year Fixed-Rate VA      30 yrs      NaN
# 12            offline               20-Year Fixed Rate      20 yrs      NaN
# 13            offline               15-Year Fixed Rate      15 yrs      NaN
# 14            offline                          7/1 ARM      30 yrs      NaN
# 15            offline                          5/1 ARM      30 yrs      NaN
# 16            offline         30-Year Fixed-Rate Jumbo      30 yrs      NaN
# 17            offline         15-Year Fixed-Rate Jumbo      15 yrs      NaN
# 18            offline                    7/1 ARM Jumbo      30 yrs      NaN
# 19            offline                   10/1 ARM Jumbo      30 yrs      NaN
#
#    Product_Interest Product_Apy Mortgage_Down_Payment Mortgage_Loan  \
# 0            4.490%         NaN                   20%     $200,000
# 1            3.990%         NaN                   20%     $200,000
# 2            4.625%         NaN                   25%     $500,000
# 3            4.125%         NaN                   20%     $200,000
# 4            3.990%         NaN                   20%     $200,000
# 5            4.400%         NaN                    4%     $200,000
# 6            4.400%         NaN                    0%     $200,000
# 7            4.500%         NaN                    0%     $200,000
# 8            5.490%         NaN                    0%     $200,000
# 0            4.500%         NaN                   20%    300,000.00
# 1            4.375%         NaN                   20%    300,000.00
# 2            4.250%         NaN                   20%    300,000.00
# 3            4.625%         NaN                   20%    300,000.00
# 4            4.500%         NaN                   20%    300,000.00
# 5            4.375%         NaN                   20%    300,000.00
# 6            4.250%         NaN                   20%    300,000.00
# 7            4.125%         NaN                   20%    300,000.00
# 8            4.000%         NaN                   20%    300,000.00
# 9            4.125%         NaN                   20%    300,000.00
# 10           4.000%         NaN                   20%    300,000.00
# 11           3.875%         NaN                   20%    300,000.00
# 12           4.000%         NaN                   20%    300,000.00
# 13           3.875%         NaN                   20%    300,000.00
# 14           3.750%         NaN                   20%    300,000.00
# 15           4.375%         NaN                   20%    300,000.00
# 16           4.250%         NaN                   20%    300,000.00
# 17           4.125%         NaN                   20%    300,000.00
# 18           4.000%         NaN                   20%    300,000.00
# 19           3.875%         NaN                   20%    300,000.00
# 20           3.750%         NaN                   20%    300,000.00
# ..              ...         ...                   ...           ...
# 23            4.00%         NaN                   20%        300000
# 24            4.13%         NaN                   20%        500000
# 25            3.88%         NaN                   20%        500000
# 26            3.13%         NaN                   20%        500000
# 27            3.38%         NaN                   20%        500000
# 28            3.75%         NaN                   20%        500000
# 29            4.38%         NaN                   20%        500000
# 30            3.75%         NaN                   20%        500000
# 31            4.50%         NaN                   20%        500000
# 32            4.00%         NaN                   20%        500000
# 0             4.63%         NaN                25.00%     $200,000
# 1             4.63%         NaN                 0.00%     $200,000
# 2             4.38%         NaN                25.00%     $200,000
# 3             4.13%         NaN                25.00%     $200,000
# 4             4.25%         NaN                25.00%     $200,000
# 5             4.13%         NaN                25.00%     $200,000
# 6             4.63%         NaN                25.00%     $750,000
# 7             4.38%         NaN                25.00%     $750,000
# 8             4.13%         NaN                25.00%     $750,000
# 9             4.25%         NaN                25.00%     $750,000
# 10            4.75%         NaN                25.00%     $200,000
# 11            4.63%         NaN                 0.00%     $200,000
# 12            4.50%         NaN                25.00%     $200,000
# 13            4.25%         NaN                25.00%     $200,000
# 14            4.25%         NaN                25.00%     $200,000
# 15            4.13%         NaN                25.00%     $200,000
# 16            4.63%         NaN                25.00%     $750,000
# 17            4.38%         NaN                25.00%     $750,000
# 18            4.25%         NaN                25.00%     $750,000
# 19            4.38%         NaN                25.00%     $750,000
#
#    Min_Credit_Score_Mortagage Mortgage_Apr
# 0                         720      4.5967%
# 1                         720      4.1629%
# 2                         720      4.6727%
# 3                         720      4.5992%
# 4                         720      4.4603%
# 5                         660      5.4812%
# 6                         720      4.6510%
# 7                         720      4.9295%
# 8                         720      5.0440%
# 0                        720+       4.528%
# 1                        720+       4.449%
# 2                        720+       4.377%
# 3                        720+       4.625%
# 4                        720+       4.544%
# 5                        720+       4.473%
# 6                        720+       4.296%
# 7                        720+       4.259%
# 8                        720+       4.195%
# 9                        720+       4.125%
# 10                       720+       4.068%
# 11                       720+       4.012%
# 12                       720+       4.088%
# 13                       720+       4.039%
# 14                       720+       3.986%
# 15                       720+       4.549%
# 16                       720+       4.479%
# 17                       720+       4.406%
# 18                       720+       4.339%
# 19                       720+       4.273%
# 20                       720+       4.239%
# ..                        ...          ...
# 23                       720+        4.49%
# 24                       720+        4.24%
# 25                       720+        4.02%
# 26                       720+        4.42%
# 27                       720+        4.34%
# 28                       720+        4.33%
# 29                       720+        5.21%
# 30                       720+        5.12%
# 31                       720+        4.77%
# 32                       720+        4.55%
# 0                         740        4.67%
# 1                         740        4.94%
# 2                         740        4.49%
# 3                         740        4.26%
# 4                         740        4.57%
# 5                         740        4.58%
# 6                         740        4.63%
# 7                         740        4.39%
# 8                         740        4.46%
# 9                         740        4.46%
# 10                        740        4.78%
# 11                        740        4.92%
# 12                        740        4.54%
# 13                        740        4.32%
# 14                        740        4.57%
# 15                        740        4.58%
# 16                        740        4.63%
# 17                        740        4.40%
# 18                        740        4.51%
# 19                        740        4.52%
#
# [152 rows x 14 columns]

# %%
df_mortgage.dropna(axis=0, how='all', inplace=True)

# %%
df_mortgage.drop(columns=["Product_Apy"], inplace=True)

# %%
df_mortgage.rename(columns={"Balance": "Min_Loan_Amount", "Product_Term": "Term_in_Year","Product_Interest": "Interest","Mortgage_Loan": "Mortgage_Loan_Amt","Min_Credit_Score_Mortagage":"Credit_Score", "Mortgage_Apr":"APR"}, inplace = True,index=str)

# %%
df_mortgage['Date'] = now.strftime("%m/%d/%Y")
df_mortgage['Bank_Native_Country'] = "US"
df_mortgage['State'] = "New York"
df_mortgage['Bank_Local_Currency'] = "USD"
df_mortgage['Bank_Type'] = "Bank"
df_mortgage['Bank_Product'] = "Mortgages"
df_mortgage['Bank_Product_Type'] = "Mortgages"
df_mortgage['Bank_Product_Code'] = np.NAN
df_mortgage['Min_Loan_Amount'] = np.NAN
df_mortgage['Interest_Type'] = "Fixed"
df_mortgage['Mortgage_Category'] = "New Purchase"
df_mortgage['Mortgage_Reason'] = "Primary Residence"
df_mortgage['Mortgage_Pymt_Mode'] = "Principal + Interest"

# %%
df_mortgage.columns
# Out:
# Index(['Date', 'Bank_Name', 'Bank_Product', 'Bank_Product_Type',
#        'Bank_Offer_Feature', 'Bank_Product_Name', 'Term_in_Year',
#        'Min_Loan_Amount', 'Interest', 'Mortgage_Down_Payment',
#        'Mortgage_Loan_Amt', 'Credit_Score', 'APR', 'Bank_Native_Country',
#        'State', 'Bank_Local_Currency', 'Bank_Type', 'Bank_Product_Code',
#        'Interest_Type', 'Mortgage_Category', 'Mortgage_Reason',
#        'Mortgage_Pymt_Mode'],
#       dtype='object')

# %%
arranged_cols = ['Date', 'Bank_Native_Country','State','Bank_Name', 'Bank_Local_Currency','Bank_Type','Bank_Product', 'Bank_Product_Type','Bank_Product_Code','Bank_Product_Name','Min_Loan_Amount','Bank_Offer_Feature','Term_in_Year','Interest_Type','Interest','APR','Mortgage_Loan_Amt','Mortgage_Down_Payment', 'Credit_Score','Mortgage_Category', 'Mortgage_Reason','Mortgage_Pymt_Mode']

# %%
df_mortgage = df_mortgage.reindex(columns= arranged_cols)

# %%
for idx in range(len(df_mortgage.index)):
    #print(df_mortgage['Bank_Product_Name'].iloc[idx])
    #print(type(df_mortgage['Bank_Product_Name'].iloc[idx]))
    if "ARM" in df_mortgage['Bank_Product_Name'].iloc[idx] or "Adjustable Rate" in df_mortgage['Bank_Product_Name'].iloc[idx]:
        df_mortgage['Interest_Type'].iloc[idx] = "Variable"

# %%
df_mortgage.to_csv(output_path+"US\\" + "US_Mortgage_Data_{}.csv".format(now.strftime("%m_%d_%Y")), index=False )
