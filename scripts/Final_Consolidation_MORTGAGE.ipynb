# %%
import glob
import os
import pandas as pd
import numpy as np
import datetime
import warnings
from maks_lib import output_path
from maks_lib import input_path
warnings.simplefilter(action='ignore')
now = datetime.datetime.now()

extension = 'csv'

# %%
all_files = glob.glob(output_path+'*.{}'.format(extension))
all_mortage_files  = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and "Mortgage" in file.split("\\")[-1]]
all_deposite_files = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and file not in all_mortage_files]

# %%
COLUMN_NAMES = list(pd.read_csv(all_mortage_files[0]).columns)
df_mortgage = pd.DataFrame(columns=COLUMN_NAMES) 
df_deposit = pd.DataFrame(columns=COLUMN_NAMES)

# %%
df_mortgage
# Out:
# Empty DataFrame
# Columns: [Date, Bank_Name, Bank_Product, Bank_Product_Type, Bank_Offer_Feature, Bank_Product_Name, Product_Term, Balance, Product_Interest, Product_Apy, Mortgage_Down_Payment, Mortgage_Loan, Min_Credit_Score_Mortagage, Mortgage_Apr]
# Index: []

# %%
for idx, file in enumerate(all_mortage_files):
    print(file)
    print(pd.read_csv(all_mortage_files[idx]).shape[1])
# Out:
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_ALLY_Data_Mortgage_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_BOA_Data_Mortgage03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_CITI_Data_Mortgage_03_08_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_JPMorgan_Data_Mortgage.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_PNC_Data_Mortgage_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_SunTrust_Data_Mortgage_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_WellsF_Data_Mortgage_03_09_2018.csv
# 14

# %%
for file in all_mortage_files:
    df_temp =pd.read_csv(file)
    df_temp.columns = ['Date', 'Bank_Name', 'Bank_Product', 'Bank_Product_Type',
       'Bank_Offer_Feature', 'Bank_Product_Name', 'Product_Term', 'Balance',
       'Product_Interest', 'Product_Apy', 'Mortgage_Down_Payment',
       'Mortgage_Loan', 'Min_Credit_Score_Mortagage', 'Mortgage_Apr']
    df_mortgage = pd.concat([df_mortgage, df_temp])

# %%
df_mortgage.shape
# Out:
# (150, 14)

# %%
df_mortgage
# Out:
#           Date                         Bank_Name Bank_Product  \
# 0   03-09-2018                              ALLY    Mortgages
# 1   03-09-2018                              ALLY    Mortgages
# 2   03-09-2018                              ALLY    Mortgages
# 3   03-09-2018                              ALLY    Mortgages
# 4   03-09-2018                              ALLY    Mortgages
# 5   03-09-2018                              ALLY    Mortgages
# 6   03-09-2018                              ALLY    Mortgages
# 7   03-09-2018                              ALLY    Mortgages
# 8   03-09-2018                              ALLY    Mortgages
# 9   03-09-2018                              ALLY    Mortgages
# 10  03-09-2018                              ALLY    Mortgages
# 11  03-09-2018                              ALLY    Mortgages
# 12  03-09-2018                              ALLY    Mortgages
# 13  03-09-2018                              ALLY    Mortgages
# 14  03-09-2018                              ALLY    Mortgages
# 15  03-09-2018                              ALLY    Mortgages
# 16  03-09-2018                              ALLY    Mortgages
# 17  03-09-2018                              ALLY    Mortgages
# 18  03-09-2018                              ALLY    Mortgages
# 19  03-09-2018                              ALLY    Mortgages
# 20  03-09-2018                              ALLY    Mortgages
# 21  03-09-2018                              ALLY    Mortgages
# 22  03-09-2018                              ALLY    Mortgages
# 23  03-09-2018                              ALLY    Mortgages
# 24  03-09-2018                              ALLY    Mortgages
# 25  03-09-2018                              ALLY    Mortgages
# 26  03-09-2018                              ALLY    Mortgages
# 27  03-09-2018                              ALLY    Mortgages
# 28  03-09-2018                              ALLY    Mortgages
# 29  03-09-2018                              ALLY    Mortgages
# ..         ...                               ...          ...
# 32    3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages
# 0   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 1   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 2   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 3   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 4   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 5   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 6   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 7   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 8   03-09-2018                SUNTRUST BANKS INC    Mortgages
# 0     3/9/2018                        Wellsfargo    Mortgages
# 1     3/9/2018                        Wellsfargo    Mortgages
# 2     3/9/2018                        Wellsfargo    Mortgages
# 3     3/9/2018                        Wellsfargo    Mortgages
# 4     3/9/2018                        Wellsfargo    Mortgages
# 5     3/9/2018                        Wellsfargo    Mortgages
# 6     3/9/2018                        Wellsfargo    Mortgages
# 7     3/9/2018                        Wellsfargo    Mortgages
# 8     3/9/2018                        Wellsfargo    Mortgages
# 9     3/9/2018                        Wellsfargo    Mortgages
# 10    3/9/2018                        Wellsfargo    Mortgages
# 11    3/9/2018                        Wellsfargo    Mortgages
# 12    3/9/2018                        Wellsfargo    Mortgages
# 13    3/9/2018                        Wellsfargo    Mortgages
# 14    3/9/2018                        Wellsfargo    Mortgages
# 15    3/9/2018                        Wellsfargo    Mortgages
# 16    3/9/2018                        Wellsfargo    Mortgages
# 17    3/9/2018                        Wellsfargo    Mortgages
# 18    3/9/2018                        Wellsfargo    Mortgages
# 19    3/9/2018                        Wellsfargo    Mortgages
#
#    Bank_Product_Type Bank_Offer_Feature                Bank_Product_Name  \
# 0          Mortgages             Online      Fixed Rate Mortgage _ 30-yr
# 1          Mortgages             Online      Fixed Rate Mortgage _ 30-yr
# 2          Mortgages             Online      Fixed Rate Mortgage _ 30-yr
# 3          Mortgages             Online      Fixed Rate Mortgage _ 25-yr
# 4          Mortgages             Online      Fixed Rate Mortgage _ 25-yr
# 5          Mortgages             Online      Fixed Rate Mortgage _ 25-yr
# 6          Mortgages             Online      Fixed Rate Mortgage _ 20-yr
# 7          Mortgages             Online      Fixed Rate Mortgage _ 20-yr
# 8          Mortgages             Online      Fixed Rate Mortgage _ 20-yr
# 9          Mortgages             Online      Fixed Rate Mortgage _ 15-yr
# 10         Mortgages             Online      Fixed Rate Mortgage _ 15-yr
# 11         Mortgages             Online      Fixed Rate Mortgage _ 15-yr
# 12         Mortgages             Online      Fixed Rate Mortgage _ 10-yr
# 13         Mortgages             Online      Fixed Rate Mortgage _ 10-yr
# 14         Mortgages             Online      Fixed Rate Mortgage _ 10-yr
# 15         Mortgages             Online  Adjustable Rate Mortgage _ 10/1
# 16         Mortgages             Online  Adjustable Rate Mortgage _ 10/1
# 17         Mortgages             Online  Adjustable Rate Mortgage _ 10/1
# 18         Mortgages             Online  Adjustable Rate Mortgage _ 10/1
# 19         Mortgages             Online  Adjustable Rate Mortgage _ 10/1
# 20         Mortgages             Online  Adjustable Rate Mortgage _ 10/1
# 21         Mortgages             Online   Adjustable Rate Mortgage _ 7/1
# 22         Mortgages             Online   Adjustable Rate Mortgage _ 7/1
# 23         Mortgages             Online   Adjustable Rate Mortgage _ 7/1
# 24         Mortgages             Online   Adjustable Rate Mortgage _ 7/1
# 25         Mortgages             Online   Adjustable Rate Mortgage _ 7/1
# 26         Mortgages             Online   Adjustable Rate Mortgage _ 7/1
# 27         Mortgages             Online   Adjustable Rate Mortgage _ 7/1
# 28         Mortgages             Online   Adjustable Rate Mortgage _ 5/1
# 29         Mortgages             Online   Adjustable Rate Mortgage _ 5/1
# ..               ...                ...                              ...
# 32         Mortgages            Offline                       VA 5-1 ARM
# 0          Mortgages            Offline             Agency 30 Year Fixed
# 1          Mortgages            Offline             Agency 15 Year Fixed
# 2          Mortgages            Offline              Jumbo 30 Year Fixed
# 3          Mortgages            Offline           Agency 30 Year 5/1 ARM
# 4          Mortgages            Offline           Agency 30 Year 7/1 ARM
# 5          Mortgages            Offline                FHA 30 Year Fixed
# 6          Mortgages            Offline                 VA 30 Year Fixed
# 7          Mortgages            Offline                 VA 15 Year Fixed
# 8          Mortgages            Offline               VA 30 Year 5/1 ARM
# 0          Mortgages            Offline               30-Year Fixed Rate
# 1          Mortgages            Offline            30-Year Fixed-Rate VA
# 2          Mortgages            Offline               15-Year Fixed Rate
# 3          Mortgages            Offline                          7/1 ARM
# 4          Mortgages            Offline                          5/1 ARM
# 5          Mortgages            Offline         30-Year Fixed-Rate Jumbo
# 6          Mortgages            Offline         15-Year Fixed-Rate Jumbo
# 7          Mortgages            Offline               20-Year Fixed Rate
# 8          Mortgages            Offline                    7/1 ARM Jumbo
# 9          Mortgages            Offline                   10/1 ARM Jumbo
# 10         Mortgages            Offline               30-Year Fixed Rate
# 11         Mortgages            Offline               20-Year Fixed Rate
# 12         Mortgages            Offline               15-Year Fixed Rate
# 13         Mortgages            Offline                          5/1 ARM
# 14         Mortgages            Offline         30-Year Fixed-Rate Jumbo
# 15         Mortgages            Offline         15-Year Fixed-Rate Jumbo
# 16         Mortgages            Offline                    7/1 ARM Jumbo
# 17         Mortgages            Offline                   10/1 ARM Jumbo
# 18         Mortgages            Offline            30-Year Fixed-Rate VA
# 19         Mortgages            Offline                          7/1 ARM
#
#     Product_Term  Balance Product_Interest  Product_Apy Mortgage_Down_Payment  \
# 0           30.0      NaN           4.500%          NaN                   20%
# 1           30.0      NaN           4.375%          NaN                   20%
# 2           30.0      NaN           4.250%          NaN                   20%
# 3           25.0      NaN           4.625%          NaN                   20%
# 4           25.0      NaN           4.500%          NaN                   20%
# 5           25.0      NaN           4.375%          NaN                   20%
# 6           20.0      NaN           4.250%          NaN                   20%
# 7           20.0      NaN           4.125%          NaN                   20%
# 8           20.0      NaN           4.000%          NaN                   20%
# 9           15.0      NaN           4.125%          NaN                   20%
# 10          15.0      NaN           4.000%          NaN                   20%
# 11          15.0      NaN           3.875%          NaN                   20%
# 12          10.0      NaN           4.000%          NaN                   20%
# 13          10.0      NaN           3.875%          NaN                   20%
# 14          10.0      NaN           3.750%          NaN                   20%
# 15          30.0      NaN           4.375%          NaN                   20%
# 16          30.0      NaN           4.250%          NaN                   20%
# 17          30.0      NaN           4.125%          NaN                   20%
# 18          30.0      NaN           4.000%          NaN                   20%
# 19          30.0      NaN           3.875%          NaN                   20%
# 20          30.0      NaN           3.750%          NaN                   20%
# 21          30.0      NaN           4.500%          NaN                   20%
# 22          30.0      NaN           4.375%          NaN                   20%
# 23          30.0      NaN           4.250%          NaN                   20%
# 24          30.0      NaN           4.125%          NaN                   20%
# 25          30.0      NaN           4.000%          NaN                   20%
# 26          30.0      NaN           3.875%          NaN                   20%
# 27          30.0      NaN           3.750%          NaN                   20%
# 28          30.0      NaN           4.375%          NaN                   20%
# 29          30.0      NaN           4.250%          NaN                   20%
# ..           ...      ...              ...          ...                   ...
# 32          30.0      NaN            4.00%          NaN                   20%
# 0           30.0      NaN           4.600%          NaN                   20%
# 1           15.0      NaN           3.900%          NaN                   20%
# 2           30.0      NaN           4.625%          NaN                   25%
# 3           30.0      NaN           4.200%          NaN                   20%
# 4           30.0      NaN           3.990%          NaN                   20%
# 5           30.0      NaN           4.400%          NaN                    4%
# 6           30.0      NaN           4.400%          NaN                    0%
# 7           15.0      NaN           4.500%          NaN                    0%
# 8           30.0      NaN           5.490%          NaN                    0%
# 0           30.0      NaN            4.63%          NaN                25.00%
# 1           30.0      NaN            4.63%          NaN                 0.00%
# 2           15.0      NaN            4.13%          NaN                25.00%
# 3           30.0      NaN            4.25%          NaN                25.00%
# 4           30.0      NaN            4.13%          NaN                25.00%
# 5           30.0      NaN            4.63%          NaN                25.00%
# 6           15.0      NaN            4.38%          NaN                25.00%
# 7           20.0      NaN            4.38%          NaN                25.00%
# 8           30.0      NaN            4.13%          NaN                25.00%
# 9           30.0      NaN            4.25%          NaN                25.00%
# 10          30.0      NaN            4.75%          NaN                25.00%
# 11          20.0      NaN            4.50%          NaN                25.00%
# 12          15.0      NaN            4.25%          NaN                25.00%
# 13          30.0      NaN            4.25%          NaN                25.00%
# 14          30.0      NaN            4.63%          NaN                25.00%
# 15          15.0      NaN            4.50%          NaN                25.00%
# 16          30.0      NaN            4.25%          NaN                25.00%
# 17          30.0      NaN            4.38%          NaN                25.00%
# 18          30.0      NaN            4.63%          NaN                 0.00%
# 19          30.0      NaN            4.38%          NaN                25.00%
#
#    Mortgage_Loan Min_Credit_Score_Mortagage Mortgage_Apr
# 0        300,000                       720+       4.528%
# 1        300,000                       720+       4.449%
# 2        300,000                       720+       4.377%
# 3        300,000                       720+       4.625%
# 4        300,000                       720+       4.544%
# 5        300,000                       720+       4.473%
# 6        300,000                       720+       4.296%
# 7        300,000                       720+       4.259%
# 8        300,000                       720+       4.195%
# 9        300,000                       720+       4.125%
# 10       300,000                       720+       4.068%
# 11       300,000                       720+       4.012%
# 12       300,000                       720+       4.088%
# 13       300,000                       720+       4.039%
# 14       300,000                       720+       3.986%
# 15       300,000                       720+       4.549%
# 16       300,000                       720+       4.479%
# 17       300,000                       720+       4.406%
# 18       300,000                       720+       4.339%
# 19       300,000                       720+       4.273%
# 20       300,000                       720+       4.239%
# 21       300,000                       720+       4.657%
# 22       300,000                       720+       4.610%
# 23       300,000                       720+       4.556%
# 24       300,000                       720+       4.499%
# 25       300,000                       720+       4.449%
# 26       300,000                       720+       4.399%
# 27       300,000                       720+       4.378%
# 28       300,000                       720+       4.650%
# 29       300,000                       720+       4.614%
# ..           ...                        ...          ...
# 32        500000                       720+        4.55%
# 0         200000                        720      4.6660%
# 1         200000                        720      4.0172%
# 2         500000                        720      4.6796%
# 3         200000                        720      4.6183%
# 4         200000                        720      4.4650%
# 5         200000                        660      5.4888%
# 6         200000                        720      4.6580%
# 7         200000                        720      4.9251%
# 8         200000                        720      5.0466%
# 0      $200,000                         740        4.68%
# 1      $200,000                         740        4.94%
# 2      $200,000                         740        4.26%
# 3      $200,000                         740        4.58%
# 4      $200,000                         740        4.59%
# 5      $750,000                         740        4.63%
# 6      $750,000                         740        4.39%
# 7      $200,000                         740        4.49%
# 8      $750,000                         740        4.46%
# 9      $750,000                         740        4.46%
# 10     $200,000                         740        4.78%
# 11     $200,000                         740        4.55%
# 12     $200,000                         740        4.32%
# 13     $200,000                         740        4.60%
# 14     $750,000                         740        4.64%
# 15     $750,000                         740        4.51%
# 16     $750,000                         740        4.51%
# 17     $750,000                         740        4.52%
# 18     $200,000                         740        4.92%
# 19     $200,000                         740        4.60%
#
# [150 rows x 14 columns]

# %%
df_mortgage.dropna(axis=0, how='all', inplace=True)

# %%
df_mortgage.drop(columns=["Product_Apy"], inplace=True)

# %%
df_mortgage.rename(columns={"Balance": "Min_Loan_Amount", "Product_Term": "Term_in_Year","Product_Interest": "Interest","Mortgage_Loan": "Mortgage_Loan_Amt","Min_Credit_Score_Mortagage":"Credit_Score", "Mortgage_Apr":"APR"}, inplace = True,index=str)

# %%
df_mortgage['Date'] = now.strftime("%m/%d/%Y")
df_mortgage['Bank_Native_Country'] = "US"
df_mortgage['State'] = "New York"
df_mortgage['Bank_Local_Currency'] = "USD"
df_mortgage['Bank_Type'] = "Bank"
df_mortgage['Bank_Product'] = "Mortgages"
df_mortgage['Bank_Product_Type'] = "Mortgages"
df_mortgage['Bank_Product_Code'] = np.NAN
df_mortgage['Min_Loan_Amount'] = np.NAN
df_mortgage['Interest_Type'] = "Fixed"
df_mortgage['Mortgage_Category'] = "New Purchase"
df_mortgage['Mortgage_Reason'] = "Primary Residence"
df_mortgage['Mortgage_Pymt_Mode'] = "Principal + Interest"

# %%
df_mortgage.columns
# Out:
# Index(['Date', 'Bank_Name', 'Bank_Product', 'Bank_Product_Type',
#        'Bank_Offer_Feature', 'Bank_Product_Name', 'Term_in_Year',
#        'Min_Loan_Amount', 'Interest', 'Mortgage_Down_Payment',
#        'Mortgage_Loan_Amt', 'Credit_Score', 'APR', 'Bank_Native_Country',
#        'State', 'Bank_Local_Currency', 'Bank_Type', 'Bank_Product_Code',
#        'Interest_Type', 'Mortgage_Category', 'Mortgage_Reason',
#        'Mortgage_Pymt_Mode'],
#       dtype='object')

# %%
arranged_cols = ['Date', 'Bank_Native_Country','State','Bank_Name', 'Bank_Local_Currency','Bank_Type','Bank_Product', 'Bank_Product_Type','Bank_Product_Code','Bank_Product_Name','Min_Loan_Amount','Bank_Offer_Feature','Term_in_Year','Interest_Type','Interest','APR','Mortgage_Loan_Amt','Mortgage_Down_Payment', 'Credit_Score','Mortgage_Category', 'Mortgage_Reason','Mortgage_Pymt_Mode']

# %%
df_mortgage = df_mortgage.reindex(columns= arranged_cols)

# %%
for idx in range(len(df_mortgage.index)):
    if "ARM" in df_mortgage['Bank_Product_Name'].iloc[idx] or "Adjustable Rate" in df_mortgage['Bank_Product_Name'].iloc[idx]:
        df_mortgage['Interest_Type'].iloc[idx] = "Variable"

# %%
for idx in range(len(df_mortgage.index)):
    #print(df_mortgage['Bank_Product_Name'].iloc[idx])
    #print(type(df_mortgage['Bank_Product_Name'].iloc[idx]))
    df_mortgage['Bank_Product_Code'].iloc[idx] = "{0}{1}{2}{3}".format(int(df_mortgage['Term_in_Year'].iloc[idx]),"Y", "M", df_mortgage['Interest_Type'].iloc[idx][0])
    #print(df_mortgage['Interest_Type'].iloc[idx])

# %%
df_mortgage.to_csv(output_path+"US\\" + "US_Mortgage_Data_{}.csv".format(now.strftime("%m_%d_%Y")), index=False )
