# %%
import glob
import os
import pandas as pd
import numpy as np
import datetime
import warnings
from maks_lib import output_path
from maks_lib import input_path
warnings.simplefilter(action='ignore')
now = datetime.datetime.now()

extension = 'csv'

# %%
all_files = glob.glob(output_path+'*.{}'.format(extension))
all_mortage_files  = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and "Mortgage" in file.split("\\")[-1]]
all_deposite_files = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and file not in all_mortage_files]

# %%
COLUMN_NAMES = list(pd.read_csv(all_mortage_files[0]).columns)
df_mortgage = pd.DataFrame(columns=COLUMN_NAMES) 
df_deposit = pd.DataFrame(columns=COLUMN_NAMES)

# %%
for idx, file in enumerate(all_deposite_files):
    print(file)
    print(pd.read_csv(all_deposite_files[idx]).shape[1])
# Out:
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_ALLY_Data_Deposit_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_CapitalOne_Data_Deposit_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_CITI_Data_Deposit_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_PNC_Data_Deposit_03-08-2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_SunTrust_Data_Deposit_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_Sync_Data_Deposit03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_WellsF_Data_Checking_Acc03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\data\output\Consolidate_WellsF_Data_Saving_Acc03_09_2018.csv
# 14

# %%
for file in all_deposite_files:
    df_temp =pd.read_csv(file)
    df_temp.columns = ['Date', 'Bank_Name', 'Bank_Product', 'Bank_Product_Type',
       'Bank_Offer_Feature', 'Bank_Product_Name', 'Product_Term', 'Balance',
       'Product_Interest', 'Product_Apy', 'Mortgage_Down_Payment',
       'Mortgage_Loan', 'Min_Credit_Score_Mortagage', 'Mortgage_Apr']
    df_deposit = pd.concat([df_deposit, df_temp])

# %%
df_deposit.shape
# Out:
# (244, 14)

# %%
df_deposit
# Out:
#           Date    Bank_Name Bank_Product Bank_Product_Type Bank_Offer_Feature  \
# 0   03-09-2018         ALLY     Deposits           Savings             Online
# 1   03-09-2018         ALLY     Deposits           Savings             Online
# 2   03-09-2018         ALLY     Deposits           Savings             Online
# 3   03-09-2018         ALLY     Deposits           Savings             Online
# 4   03-09-2018         ALLY     Deposits                CD             Online
# 5   03-09-2018         ALLY     Deposits                CD             Online
# 6   03-09-2018         ALLY     Deposits                CD             Online
# 7   03-09-2018         ALLY     Deposits                CD             Online
# 8   03-09-2018         ALLY     Deposits                CD             Online
# 9   03-09-2018         ALLY     Deposits                CD             Online
# 10  03-09-2018         ALLY     Deposits                CD             Online
# 11  03-09-2018         ALLY     Deposits                CD             Online
# 12  03-09-2018         ALLY     Deposits                CD             Online
# 13  03-09-2018         ALLY     Deposits                CD             Online
# 14  03-09-2018         ALLY     Deposits                CD             Online
# 15  03-09-2018         ALLY     Deposits                CD             Online
# 16  03-09-2018         ALLY     Deposits                CD             Online
# 17  03-09-2018         ALLY     Deposits                CD             Online
# 18  03-09-2018         ALLY     Deposits                CD             Online
# 19  03-09-2018         ALLY     Deposits                CD             Online
# 20  03-09-2018         ALLY     Deposits                CD             Online
# 21  03-09-2018         ALLY     Deposits                CD             Online
# 22  03-09-2018         ALLY     Deposits                CD             Online
# 23  03-09-2018         ALLY     Deposits                CD             Online
# 24  03-09-2018         ALLY     Deposits                CD             Online
# 25  03-09-2018         ALLY     Deposits                CD             Online
# 26  03-09-2018         ALLY     Deposits                CD             Online
# 27  03-09-2018         ALLY     Deposits                CD             Online
# 28  03-09-2018         ALLY     Deposits                CD             Online
# 29  03-09-2018         ALLY     Deposits                CD             Online
# ..         ...          ...          ...               ...                ...
# 0   03-09-2018  Wells Fargo     Deposits          Checking            Offline
# 0     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 1     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 2     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 3     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 4     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 5     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 6     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 7     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 8     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 9     3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 10    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 11    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 12    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 13    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 14    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 15    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 16    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 17    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 18    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 19    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 20    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 21    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 22    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 23    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 24    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 25    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 26    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 27    3/9/2018  WELLS FARGO     Deposits           Savings            Offline
# 28         NaN          NaN          NaN               NaN                NaN
#
#                        Bank_Product_Name  Product_Term  \
# 0                         Online Savings           NaN
# 1                           Money Market           NaN
# 2                           Money Market           NaN
# 3                           Money Market           NaN
# 4                 High Yield CDs_3 month           3.0
# 5                 High Yield CDs_6 month           6.0
# 6                 High Yield CDs_9 month           9.0
# 7                High Yield CDs_12 month          12.0
# 8                High Yield CDs_18 month          18.0
# 9                  High Yield CDs_3 year          36.0
# 10                 High Yield CDs_5 year          60.0
# 11                High Yield CDs_3 month           3.0
# 12                High Yield CDs_6 month           6.0
# 13                High Yield CDs_9 month           9.0
# 14               High Yield CDs_12 month          12.0
# 15               High Yield CDs_18 month          18.0
# 16                 High Yield CDs_3 year          36.0
# 17                 High Yield CDs_5 year          60.0
# 18                High Yield CDs_3 month           3.0
# 19                High Yield CDs_6 month           6.0
# 20                High Yield CDs_9 month           9.0
# 21               High Yield CDs_12 month          12.0
# 22               High Yield CDs_18 month          18.0
# 23                 High Yield CDs_3 year          36.0
# 24                 High Yield CDs_5 year          60.0
# 25            Raise Your Rate CDs_2 year          24.0
# 26            Raise Your Rate CDs_4 year          48.0
# 27            Raise Your Rate CDs_2 year          24.0
# 28            Raise Your Rate CDs_4 year          48.0
# 29            Raise Your Rate CDs_2 year          24.0
# ..                                   ...           ...
# 0          Wells Fargo Everyday Checking           NaN
# 0                   Wells Fargo Way2Save           NaN
# 1    Platinum Savings - Special Interest           NaN
# 2    Platinum Savings - Special Interest           NaN
# 3    Platinum Savings - Special Interest           NaN
# 4   Platinum Savings - Standard Interest           NaN
# 5   Platinum Savings - Standard Interest           NaN
# 6                             Special CD           9.0
# 7                             Special CD          19.0
# 8                             Special CD          39.0
# 9                             Special CD          58.0
# 10                                    CD           3.0
# 11                                    CD           3.0
# 12                                    CD           3.0
# 13                                    CD           3.0
# 14                                    CD           3.0
# 15                                    CD           3.0
# 16                                    CD           6.0
# 17                                    CD           6.0
# 18                                    CD           6.0
# 19                                    CD           6.0
# 20                                    CD           6.0
# 21                                    CD           6.0
# 22                                    CD          12.0
# 23                                    CD          12.0
# 24                                    CD          12.0
# 25                                    CD          12.0
# 26                                    CD          12.0
# 27                                    CD          12.0
# 28                                   NaN           NaN
#
#                              Balance Product_Interest Product_Apy  \
# 0                                NaN              NaN       1.45%
# 1   Less than $5,000 opening deposit              NaN       0.90%
# 2     $5,000 minimum opening deposit              NaN       0.90%
# 3    $25,000 minimum opening deposit              NaN       1.00%
# 4                   Less than $5,000              NaN       1.00%
# 5                   Less than $5,000              NaN       1.50%
# 6                   Less than $5,000              NaN       1.55%
# 7                   Less than $5,000              NaN       1.75%
# 8                   Less than $5,000              NaN       1.80%
# 9                   Less than $5,000              NaN       1.85%
# 10                  Less than $5,000              NaN       2.25%
# 11                 $5,000-$24,999.99              NaN       1.25%
# 12                 $5,000-$24,999.99              NaN       1.60%
# 13                 $5,000-$24,999.99              NaN       1.65%
# 14                 $5,000-$24,999.99              NaN       1.85%
# 15                 $5,000-$24,999.99              NaN       1.95%
# 16                 $5,000-$24,999.99              NaN       2.00%
# 17                 $5,000-$24,999.99              NaN       2.40%
# 18                   $25,000 or more              NaN       1.50%
# 19                   $25,000 or more              NaN       1.75%
# 20                   $25,000 or more              NaN       1.80%
# 21                   $25,000 or more              NaN       2.00%
# 22                   $25,000 or more              NaN       2.05%
# 23                   $25,000 or more              NaN       2.10%
# 24                   $25,000 or more              NaN       2.50%
# 25                  Less than $5,000              NaN       2.00%
# 26                  Less than $5,000              NaN       2.00%
# 27                 $5,000-$24,999.99              NaN       2.00%
# 28                 $5,000-$24,999.99              NaN       2.00%
# 29                   $25,000 or more              NaN       2.00%
# ..                               ...              ...         ...
# 0                                NaN              NaN         NaN
# 0                         $0 or more            0.01%       0.01%
# 1                   $0  - $24,999.99            0.03%       0.03%
# 2              $25,000  - $99,999.99            1.25%       0.34%
# 3                  $100,000  or more            1.25%       0.35%
# 4                   $0  - $99,999.99            0.03%       0.03%
# 5                  $100,000  or more            0.05%       0.05%
# 6                                NaN            0.35%       0.35%
# 7                                NaN            1.59%       1.60%
# 8                                NaN            1.14%       1.15%
# 9                                NaN            1.19%       1.20%
# 10                    $0 - $4,999.99            0.01%       0.01%
# 11                $5,000 - $9,999.99            0.01%       0.01%
# 12              $10,000 - $24,999.99            0.01%       0.01%
# 13              $25,000 - $49,999.99            0.01%       0.01%
# 14              $50,000 - $99,999.99            0.01%       0.01%
# 15                        $100,000 +            0.01%       0.01%
# 16                    $0 - $4,999.99            0.01%       0.01%
# 17                $5,000 - $9,999.99            0.01%       0.01%
# 18              $10,000 - $24,999.99            0.01%       0.01%
# 19              $25,000 - $49,999.99            0.01%       0.01%
# 20              $50,000 - $99,999.99            0.01%       0.01%
# 21                        $100,000 +            0.01%       0.01%
# 22                    $0 - $4,999.99            0.05%       0.05%
# 23                $5,000 - $9,999.99            0.05%       0.05%
# 24              $10,000 - $24,999.99            0.05%       0.05%
# 25              $25,000 - $49,999.99            0.05%       0.05%
# 26              $50,000 - $99,999.99            0.05%       0.05%
# 27                        $100,000 +            0.05%       0.05%
# 28                               NaN              NaN         NaN
#
#     Mortgage_Down_Payment  Mortgage_Loan  Min_Credit_Score_Mortagage  \
# 0                     NaN            NaN                         NaN
# 1                     NaN            NaN                         NaN
# 2                     NaN            NaN                         NaN
# 3                     NaN            NaN                         NaN
# 4                     NaN            NaN                         NaN
# 5                     NaN            NaN                         NaN
# 6                     NaN            NaN                         NaN
# 7                     NaN            NaN                         NaN
# 8                     NaN            NaN                         NaN
# 9                     NaN            NaN                         NaN
# 10                    NaN            NaN                         NaN
# 11                    NaN            NaN                         NaN
# 12                    NaN            NaN                         NaN
# 13                    NaN            NaN                         NaN
# 14                    NaN            NaN                         NaN
# 15                    NaN            NaN                         NaN
# 16                    NaN            NaN                         NaN
# 17                    NaN            NaN                         NaN
# 18                    NaN            NaN                         NaN
# 19                    NaN            NaN                         NaN
# 20                    NaN            NaN                         NaN
# 21                    NaN            NaN                         NaN
# 22                    NaN            NaN                         NaN
# 23                    NaN            NaN                         NaN
# 24                    NaN            NaN                         NaN
# 25                    NaN            NaN                         NaN
# 26                    NaN            NaN                         NaN
# 27                    NaN            NaN                         NaN
# 28                    NaN            NaN                         NaN
# 29                    NaN            NaN                         NaN
# ..                    ...            ...                         ...
# 0                     NaN            NaN                         NaN
# 0                     NaN            NaN                         NaN
# 1                     NaN            NaN                         NaN
# 2                     NaN            NaN                         NaN
# 3                     NaN            NaN                         NaN
# 4                     NaN            NaN                         NaN
# 5                     NaN            NaN                         NaN
# 6                     NaN            NaN                         NaN
# 7                     NaN            NaN                         NaN
# 8                     NaN            NaN                         NaN
# 9                     NaN            NaN                         NaN
# 10                    NaN            NaN                         NaN
# 11                    NaN            NaN                         NaN
# 12                    NaN            NaN                         NaN
# 13                    NaN            NaN                         NaN
# 14                    NaN            NaN                         NaN
# 15                    NaN            NaN                         NaN
# 16                    NaN            NaN                         NaN
# 17                    NaN            NaN                         NaN
# 18                    NaN            NaN                         NaN
# 19                    NaN            NaN                         NaN
# 20                    NaN            NaN                         NaN
# 21                    NaN            NaN                         NaN
# 22                    NaN            NaN                         NaN
# 23                    NaN            NaN                         NaN
# 24                    NaN            NaN                         NaN
# 25                    NaN            NaN                         NaN
# 26                    NaN            NaN                         NaN
# 27                    NaN            NaN                         NaN
# 28                    NaN            NaN                         NaN
#
#     Mortgage_Apr
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ..           ...
# 0            NaN
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
#
# [244 rows x 14 columns]

# %%
df_deposit.dropna(axis=0, how='all', inplace=True)

# %%
df_deposit.drop(columns=['Mortgage_Down_Payment','Mortgage_Loan', 'Min_Credit_Score_Mortagage', 'Mortgage_Apr'], inplace=True)

# %%
df_deposit.rename(columns={"Product_Term": "Term_in_Months","Product_Interest": "Interest","Product_Apy":"APY"}, inplace = True,index=str)

# %%
df_deposit['Date'] = now.strftime("%m/%d/%Y")
df_deposit['Bank_Native_Country'] = "US"
df_deposit['State'] = "New York"
df_deposit['Bank_Local_Currency'] = "USD"
df_deposit['Bank_Type'] = "Bank"
df_deposit['Bank_Product'] = "Deposits"
df_deposit['Bank_Product_Code'] = np.NAN
df_deposit['Interest_Type'] = "Variable"
df_deposit['Minm_Balance'] = np.NAN
df_deposit['Maxm_Balance'] = np.NAN

# %%
arranged_cols = ['Date', 'Bank_Native_Country','State','Bank_Name','Bank_Local_Currency', 'Bank_Type','Bank_Product','Bank_Product_Type','Bank_Product_Code','Bank_Product_Name','Balance','Minm_Balance','Maxm_Balance','Bank_Offer_Feature','Term_in_Months', 'Interest_Type','Interest', 'APY']

# %%
df_deposit = df_deposit.reindex(columns= arranged_cols)

# %%
for idx in range(len(df_deposit.index)):
    if "CD" in df_deposit['Bank_Product_Type'].iloc[idx]:
        df_deposit['Interest_Type'].iloc[idx] = "Fixed"

# %%
for idx in range(len(df_deposit.index)):
    #print(df_mortgage['Bank_Product_Name'].iloc[idx])
    #print(type(df_mortgage['Bank_Product_Name'].iloc[idx]))
    #  CD  
    
    if "Savings" in df_deposit['Bank_Product_Type'].iloc[idx]:
        s = "SB"
    elif "Checking" in df_deposit['Bank_Product_Type'].iloc[idx]:
        s = "CC"
    else:
        s = "CD"
    try:
        t = int(df_deposit['Term_in_Months'].iloc[idx])
    except ValueError:
        t = "_"        
    df_deposit['Bank_Product_Code'].iloc[idx] = "{0}{1}{2}{3}".format(t,"M", s, df_deposit['Interest_Type'].iloc[idx][0])
    #print(df_mortgage['Interest_Type'].iloc[idx])

# %%
df_deposit.head()
# Out:
#          Date Bank_Native_Country     State Bank_Name Bank_Local_Currency  \
# 0  03/09/2018                  US  New York      ALLY                 USD
# 1  03/09/2018                  US  New York      ALLY                 USD
# 2  03/09/2018                  US  New York      ALLY                 USD
# 3  03/09/2018                  US  New York      ALLY                 USD
# 4  03/09/2018                  US  New York      ALLY                 USD
#
#   Bank_Type Bank_Product Bank_Product_Type Bank_Product_Code  \
# 0      Bank     Deposits           Savings             _MSBV
# 1      Bank     Deposits           Savings             _MSBV
# 2      Bank     Deposits           Savings             _MSBV
# 3      Bank     Deposits           Savings             _MSBV
# 4      Bank     Deposits                CD             3MCDF
#
#         Bank_Product_Name                           Balance  Minm_Balance  \
# 0          Online Savings                               NaN           NaN
# 1            Money Market  Less than $5,000 opening deposit           NaN
# 2            Money Market    $5,000 minimum opening deposit           NaN
# 3            Money Market   $25,000 minimum opening deposit           NaN
# 4  High Yield CDs_3 month                  Less than $5,000           NaN
#
#    Maxm_Balance Bank_Offer_Feature  Term_in_Months Interest_Type Interest  \
# 0           NaN             Online             NaN      Variable      NaN
# 1           NaN             Online             NaN      Variable      NaN
# 2           NaN             Online             NaN      Variable      NaN
# 3           NaN             Online             NaN      Variable      NaN
# 4           NaN             Online             3.0         Fixed      NaN
#
#      APY
# 0  1.45%
# 1  0.90%
# 2  0.90%
# 3  1.00%
# 4  1.00%

# %%
for idx in range(len(df_deposit.index)):
    if "Below" in str(df_deposit['Balance'].iloc[idx]) or "or less" in str(df_deposit['Balance'].iloc[idx]) or "Less than" in str(df_deposit['Balance'].iloc[idx]) or "less than" in str(df_deposit['Balance'].iloc[idx]) or "Up to" in str(df_deposit['Balance'].iloc[idx]):
        df_deposit['Maxm_Balance'].iloc[idx] = df_deposit['Balance'].iloc[idx]
    elif "-" in str(df_deposit['Balance'].iloc[idx]):
        df_deposit['Minm_Balance'].iloc[idx], df_deposit['Maxm_Balance'].iloc[idx] = str(df_deposit['Balance'].iloc[idx]).split("-")
    elif " to " in str(df_deposit['Balance'].iloc[idx]):
        df_deposit['Minm_Balance'].iloc[idx], df_deposit['Maxm_Balance'].iloc[idx] = str(df_deposit['Balance'].iloc[idx]).split("to")
    else:
        df_deposit['Minm_Balance'].iloc[idx] = df_deposit['Balance'].iloc[idx]

# %%
df_deposit.drop(columns=['Balance'], inplace=True)

# %%
df_deposit.to_csv(output_path+"US\\" + "US_Deposits_Data_{}.csv".format(now.strftime("%m_%d_%Y")), index=False )
