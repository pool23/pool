# %%
import glob
import os
import pandas as pd
import numpy as np
import datetime
import re
import warnings
from maks_lib import output_path
from maks_lib import input_path
warnings.simplefilter(action='ignore')
now = datetime.datetime.now()

extension = 'csv'

# %%
all_files = glob.glob(output_path+'*.{}'.format(extension))
all_mortage_files  = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and "Mortgage" in file.split("\\")[-1]]
all_deposite_files = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and file not in all_mortage_files]

# %%
COLUMN_NAMES = list(pd.read_csv(all_mortage_files[0]).columns)
df_mortgage = pd.DataFrame(columns=COLUMN_NAMES) 
df_deposit = pd.DataFrame(columns=COLUMN_NAMES)

# %%
for idx, file in enumerate(all_deposite_files):
    print(file)
    print(pd.read_csv(all_deposite_files[idx]).shape[1])
# Out:
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidated_BOA_Data_Deposit_03_08_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidated_JPM_Data_Deposit_03_08_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidate_PNC_Data_Deposit_03-08-2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidate_Sync_Data_Deposit03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidate_WellsF_Data_Checking_Acc03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidate_WellsF_Data_Saving_Acc03_09_2018.csv
# 14

# %%
for file in all_deposite_files:
    df_temp =pd.read_csv(file)
    df_temp.columns = ['Date', 'Bank_Name', 'Bank_Product', 'Bank_Product_Type',
       'Bank_Offer_Feature', 'Bank_Product_Name', 'Product_Term', 'Balance',
       'Product_Interest', 'Product_Apy', 'Mortgage_Down_Payment',
       'Mortgage_Loan', 'Min_Credit_Score_Mortagage', 'Mortgage_Apr']
    df_deposit = pd.concat([df_deposit, df_temp])

# %%
df_deposit.shape
# Out:
# (155, 14)

# %%
df_deposit
# Out:
#           Date             Bank_Name Bank_Product Bank_Product_Type  \
# 0   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 1   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 2   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 3   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 4   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 5   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 6   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 7   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 8   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 9   03-07-2018  BANK OF AMERICA CORP     Deposits           Savings
# 10  03-07-2018  BANK OF AMERICA CORP     Deposits          Checking
# 11  03-07-2018  BANK OF AMERICA CORP     Deposits          Checking
# 12  03-07-2018  BANK OF AMERICA CORP     Deposits          Checking
# 13  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 14  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 15  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 16  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 17  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 18  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 19  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 20  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 21  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 22  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 23  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 24  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 25  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 26  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 27  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 28  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# 29  03-07-2018  BANK OF AMERICA CORP     Deposits           IRA CDs
# ..         ...                   ...          ...               ...
# 0   03-09-2018           Wells Fargo     Deposits          Checking
# 0     3/9/2018           WELLS FARGO     Deposits           Savings
# 1     3/9/2018           WELLS FARGO     Deposits           Savings
# 2     3/9/2018           WELLS FARGO     Deposits           Savings
# 3     3/9/2018           WELLS FARGO     Deposits           Savings
# 4     3/9/2018           WELLS FARGO     Deposits           Savings
# 5     3/9/2018           WELLS FARGO     Deposits           Savings
# 6     3/9/2018           WELLS FARGO     Deposits           Savings
# 7     3/9/2018           WELLS FARGO     Deposits           Savings
# 8     3/9/2018           WELLS FARGO     Deposits           Savings
# 9     3/9/2018           WELLS FARGO     Deposits           Savings
# 10    3/9/2018           WELLS FARGO     Deposits           Savings
# 11    3/9/2018           WELLS FARGO     Deposits           Savings
# 12    3/9/2018           WELLS FARGO     Deposits           Savings
# 13    3/9/2018           WELLS FARGO     Deposits           Savings
# 14    3/9/2018           WELLS FARGO     Deposits           Savings
# 15    3/9/2018           WELLS FARGO     Deposits           Savings
# 16    3/9/2018           WELLS FARGO     Deposits           Savings
# 17    3/9/2018           WELLS FARGO     Deposits           Savings
# 18    3/9/2018           WELLS FARGO     Deposits           Savings
# 19    3/9/2018           WELLS FARGO     Deposits           Savings
# 20    3/9/2018           WELLS FARGO     Deposits           Savings
# 21    3/9/2018           WELLS FARGO     Deposits           Savings
# 22    3/9/2018           WELLS FARGO     Deposits           Savings
# 23    3/9/2018           WELLS FARGO     Deposits           Savings
# 24    3/9/2018           WELLS FARGO     Deposits           Savings
# 25    3/9/2018           WELLS FARGO     Deposits           Savings
# 26    3/9/2018           WELLS FARGO     Deposits           Savings
# 27    3/9/2018           WELLS FARGO     Deposits           Savings
# 28         NaN                   NaN          NaN               NaN
#
#    Bank_Offer_Feature                      Bank_Product_Name     Product_Term  \
# 0             Offline                        Rewards Savings              NaN
# 1             Offline                        Rewards Savings              NaN
# 2             Offline                   Rewards Savings Gold              NaN
# 3             Offline                   Rewards Savings Gold              NaN
# 4             Offline               Rewards Savings Platinum              NaN
# 5             Offline               Rewards Savings Platinum              NaN
# 6             Offline        Rewards Savings Platinum Honors              NaN
# 7             Offline        Rewards Savings Platinum Honors              NaN
# 8             Offline  Banking Rewards for Wealth Management              NaN
# 9             Offline  Banking Rewards for Wealth Management              NaN
# 10            Offline      Bank of America Interest Checking              NaN
# 11            Offline      Bank of America Interest Checking              NaN
# 12            Offline      Bank of America Interest Checking              NaN
# 13            Offline             Fixed Term CD/IRA Products   06 - 11 Months
# 14            Offline             Fixed Term CD/IRA Products   12 - 17 Months
# 15            Offline             Fixed Term CD/IRA Products   18 - 23 Months
# 16            Offline             Fixed Term CD/IRA Products   24 - 35 Months
# 17            Offline             Fixed Term CD/IRA Products   36 - 47 Months
# 18            Offline             Fixed Term CD/IRA Products   48 - 59 Months
# 19            Offline             Fixed Term CD/IRA Products  60 - 119 Months
# 20            Offline             Fixed Term CD/IRA Products       120 Months
# 21            Offline             Fixed Term CD/IRA Products   06 - 11 Months
# 22            Offline             Fixed Term CD/IRA Products   12 - 17 Months
# 23            Offline             Fixed Term CD/IRA Products   18 - 23 Months
# 24            Offline             Fixed Term CD/IRA Products   24 - 35 Months
# 25            Offline             Fixed Term CD/IRA Products   36 - 47 Months
# 26            Offline             Fixed Term CD/IRA Products   48 - 59 Months
# 27            Offline             Fixed Term CD/IRA Products  60 - 119 Months
# 28            Offline             Fixed Term CD/IRA Products       120 Months
# 29            Offline             Fixed Term CD/IRA Products   06 - 11 Months
# ..                ...                                    ...              ...
# 0             Offline          Wells Fargo Everyday Checking              NaN
# 0             Offline                   Wells Fargo Way2Save              NaN
# 1             Offline    Platinum Savings - Special Interest              NaN
# 2             Offline    Platinum Savings - Special Interest              NaN
# 3             Offline    Platinum Savings - Special Interest              NaN
# 4             Offline   Platinum Savings - Standard Interest              NaN
# 5             Offline   Platinum Savings - Standard Interest              NaN
# 6             Offline                             Special CD                9
# 7             Offline                             Special CD               19
# 8             Offline                             Special CD               39
# 9             Offline                             Special CD               58
# 10            Offline                                     CD                3
# 11            Offline                                     CD                3
# 12            Offline                                     CD                3
# 13            Offline                                     CD                3
# 14            Offline                                     CD                3
# 15            Offline                                     CD                3
# 16            Offline                                     CD                6
# 17            Offline                                     CD                6
# 18            Offline                                     CD                6
# 19            Offline                                     CD                6
# 20            Offline                                     CD                6
# 21            Offline                                     CD                6
# 22            Offline                                     CD               12
# 23            Offline                                     CD               12
# 24            Offline                                     CD               12
# 25            Offline                                     CD               12
# 26            Offline                                     CD               12
# 27            Offline                                     CD               12
# 28                NaN                                    NaN              NaN
#
#                   Balance Product_Interest Product_Apy  Mortgage_Down_Payment  \
# 0        Less than $2,500            0.03%       0.03%                    NaN
# 1         $2,500 and over            0.03%       0.03%                    NaN
# 2        Less than $2,500            0.04%       0.04%                    NaN
# 3         $2,500 and over            0.04%       0.04%                    NaN
# 4        Less than $2,500            0.05%       0.05%                    NaN
# 5         $2,500 and over            0.05%       0.05%                    NaN
# 6        Less than $2,500            0.06%       0.06%                    NaN
# 7         $2,500 and over            0.06%       0.06%                    NaN
# 8        Less than $2,500            0.06%       0.06%                    NaN
# 9         $2,500 and over            0.06%       0.06%                    NaN
# 10      Less than $50,000            0.01%       0.01%                    NaN
# 11      $50,000 - $99,999            0.02%       0.02%                    NaN
# 12      $100,000 and over            0.02%       0.02%                    NaN
# 13      Less than $10,000            0.03%       0.03%                    NaN
# 14      Less than $10,000            0.05%       0.05%                    NaN
# 15      Less than $10,000            0.07%       0.07%                    NaN
# 16      Less than $10,000             0.1%        0.1%                    NaN
# 17      Less than $10,000            0.55%       0.55%                    NaN
# 18      Less than $10,000            0.65%       0.65%                    NaN
# 19      Less than $10,000            0.75%       0.75%                    NaN
# 20      Less than $10,000            0.75%       0.75%                    NaN
# 21      $10,000 - $99,999            0.03%       0.03%                    NaN
# 22      $10,000 - $99,999            0.05%       0.05%                    NaN
# 23      $10,000 - $99,999            0.07%       0.07%                    NaN
# 24      $10,000 - $99,999             0.1%        0.1%                    NaN
# 25      $10,000 - $99,999            0.55%       0.55%                    NaN
# 26      $10,000 - $99,999            0.65%       0.65%                    NaN
# 27      $10,000 - $99,999            0.75%       0.75%                    NaN
# 28      $10,000 - $99,999            0.75%       0.75%                    NaN
# 29      $100,000 and over            0.03%       0.03%                    NaN
# ..                    ...              ...         ...                    ...
# 0                     NaN              NaN         NaN                    NaN
# 0              $0 or more            0.01%       0.01%                    NaN
# 1        $0  - $24,999.99            0.03%       0.03%                    NaN
# 2   $25,000  - $99,999.99            1.25%       0.34%                    NaN
# 3       $100,000  or more            1.25%       0.35%                    NaN
# 4        $0  - $99,999.99            0.03%       0.03%                    NaN
# 5       $100,000  or more            0.05%       0.05%                    NaN
# 6                     NaN            0.35%       0.35%                    NaN
# 7                     NaN            1.59%       1.60%                    NaN
# 8                     NaN            1.14%       1.15%                    NaN
# 9                     NaN            1.19%       1.20%                    NaN
# 10         $0 - $4,999.99            0.01%       0.01%                    NaN
# 11     $5,000 - $9,999.99            0.01%       0.01%                    NaN
# 12   $10,000 - $24,999.99            0.01%       0.01%                    NaN
# 13   $25,000 - $49,999.99            0.01%       0.01%                    NaN
# 14   $50,000 - $99,999.99            0.01%       0.01%                    NaN
# 15             $100,000 +            0.01%       0.01%                    NaN
# 16         $0 - $4,999.99            0.01%       0.01%                    NaN
# 17     $5,000 - $9,999.99            0.01%       0.01%                    NaN
# 18   $10,000 - $24,999.99            0.01%       0.01%                    NaN
# 19   $25,000 - $49,999.99            0.01%       0.01%                    NaN
# 20   $50,000 - $99,999.99            0.01%       0.01%                    NaN
# 21             $100,000 +            0.01%       0.01%                    NaN
# 22         $0 - $4,999.99            0.05%       0.05%                    NaN
# 23     $5,000 - $9,999.99            0.05%       0.05%                    NaN
# 24   $10,000 - $24,999.99            0.05%       0.05%                    NaN
# 25   $25,000 - $49,999.99            0.05%       0.05%                    NaN
# 26   $50,000 - $99,999.99            0.05%       0.05%                    NaN
# 27             $100,000 +            0.05%       0.05%                    NaN
# 28                    NaN              NaN         NaN                    NaN
#
#     Mortgage_Loan  Min_Credit_Score_Mortagage  Mortgage_Apr
# 0             NaN                         NaN           NaN
# 1             NaN                         NaN           NaN
# 2             NaN                         NaN           NaN
# 3             NaN                         NaN           NaN
# 4             NaN                         NaN           NaN
# 5             NaN                         NaN           NaN
# 6             NaN                         NaN           NaN
# 7             NaN                         NaN           NaN
# 8             NaN                         NaN           NaN
# 9             NaN                         NaN           NaN
# 10            NaN                         NaN           NaN
# 11            NaN                         NaN           NaN
# 12            NaN                         NaN           NaN
# 13            NaN                         NaN           NaN
# 14            NaN                         NaN           NaN
# 15            NaN                         NaN           NaN
# 16            NaN                         NaN           NaN
# 17            NaN                         NaN           NaN
# 18            NaN                         NaN           NaN
# 19            NaN                         NaN           NaN
# 20            NaN                         NaN           NaN
# 21            NaN                         NaN           NaN
# 22            NaN                         NaN           NaN
# 23            NaN                         NaN           NaN
# 24            NaN                         NaN           NaN
# 25            NaN                         NaN           NaN
# 26            NaN                         NaN           NaN
# 27            NaN                         NaN           NaN
# 28            NaN                         NaN           NaN
# 29            NaN                         NaN           NaN
# ..            ...                         ...           ...
# 0             NaN                         NaN           NaN
# 0             NaN                         NaN           NaN
# 1             NaN                         NaN           NaN
# 2             NaN                         NaN           NaN
# 3             NaN                         NaN           NaN
# 4             NaN                         NaN           NaN
# 5             NaN                         NaN           NaN
# 6             NaN                         NaN           NaN
# 7             NaN                         NaN           NaN
# 8             NaN                         NaN           NaN
# 9             NaN                         NaN           NaN
# 10            NaN                         NaN           NaN
# 11            NaN                         NaN           NaN
# 12            NaN                         NaN           NaN
# 13            NaN                         NaN           NaN
# 14            NaN                         NaN           NaN
# 15            NaN                         NaN           NaN
# 16            NaN                         NaN           NaN
# 17            NaN                         NaN           NaN
# 18            NaN                         NaN           NaN
# 19            NaN                         NaN           NaN
# 20            NaN                         NaN           NaN
# 21            NaN                         NaN           NaN
# 22            NaN                         NaN           NaN
# 23            NaN                         NaN           NaN
# 24            NaN                         NaN           NaN
# 25            NaN                         NaN           NaN
# 26            NaN                         NaN           NaN
# 27            NaN                         NaN           NaN
# 28            NaN                         NaN           NaN
#
# [155 rows x 14 columns]

# %%
df_deposit.dropna(axis=0, how='all', inplace=True)

# %%
df_deposit.drop(columns=['Mortgage_Down_Payment','Mortgage_Loan', 'Min_Credit_Score_Mortagage', 'Mortgage_Apr'], inplace=True)

# %%
df_deposit.rename(columns={"Product_Term": "Term_in_Months","Product_Interest": "Interest","Product_Apy":"APY"}, inplace = True,index=str)

# %%
df_deposit['Date'] = now.strftime("%Y-%m-%d")
df_deposit['Bank_Native_Country'] = "US"
df_deposit['State'] = "New York"
df_deposit['Bank_Local_Currency'] = "USD"
df_deposit['Bank_Type'] = "Bank"
df_deposit['Bank_Product'] = "Deposits"
df_deposit['Bank_Product_Code'] = np.NAN
df_deposit['Interest_Type'] = "Variable"
df_deposit['Minm_Balance'] = np.NAN
df_deposit['Maxm_Balance'] = np.NAN

# %%
arranged_cols = ['Date', 'Bank_Native_Country','State','Bank_Name','Bank_Local_Currency', 'Bank_Type','Bank_Product','Bank_Product_Type','Bank_Product_Code','Bank_Product_Name','Balance','Minm_Balance','Maxm_Balance','Bank_Offer_Feature','Term_in_Months', 'Interest_Type','Interest', 'APY']

# %%
df_deposit = df_deposit.reindex(columns= arranged_cols)

# %%
for idx in range(len(df_deposit.index)):
    if "CD" in df_deposit['Bank_Product_Type'].iloc[idx]:
        df_deposit['Interest_Type'].iloc[idx] = "Fixed"

# %%
for idx in range(len(df_deposit.index)):
    #print(df_mortgage['Bank_Product_Name'].iloc[idx])
    #print(type(df_mortgage['Bank_Product_Name'].iloc[idx]))
    #  CD  
    
    if "Savings" in df_deposit['Bank_Product_Type'].iloc[idx]:
        s = "SB"
    elif "Checking" in df_deposit['Bank_Product_Type'].iloc[idx]:
        s = "CC"
    else:
        s = "CD"
    try:
        t = int(df_deposit['Term_in_Months'].iloc[idx])
    except ValueError:
        t = "_"        
    df_deposit['Bank_Product_Code'].iloc[idx] = "{0}{1}{2}{3}".format(t,"M", s, df_deposit['Interest_Type'].iloc[idx][0])
    #print(df_mortgage['Interest_Type'].iloc[idx])

# %%
df_deposit.head()
# Out:
#          Date Bank_Native_Country     State             Bank_Name  \
# 0  2018-03-12                  US  New York  BANK OF AMERICA CORP
# 1  2018-03-12                  US  New York  BANK OF AMERICA CORP
# 2  2018-03-12                  US  New York  BANK OF AMERICA CORP
# 3  2018-03-12                  US  New York  BANK OF AMERICA CORP
# 4  2018-03-12                  US  New York  BANK OF AMERICA CORP
#
#   Bank_Local_Currency Bank_Type Bank_Product Bank_Product_Type  \
# 0                 USD      Bank     Deposits           Savings
# 1                 USD      Bank     Deposits           Savings
# 2                 USD      Bank     Deposits           Savings
# 3                 USD      Bank     Deposits           Savings
# 4                 USD      Bank     Deposits           Savings
#
#   Bank_Product_Code         Bank_Product_Name           Balance  Minm_Balance  \
# 0             _MSBV           Rewards Savings  Less than $2,500           NaN
# 1             _MSBV           Rewards Savings   $2,500 and over           NaN
# 2             _MSBV      Rewards Savings Gold  Less than $2,500           NaN
# 3             _MSBV      Rewards Savings Gold   $2,500 and over           NaN
# 4             _MSBV  Rewards Savings Platinum  Less than $2,500           NaN
#
#    Maxm_Balance Bank_Offer_Feature Term_in_Months Interest_Type Interest  \
# 0           NaN            Offline            NaN      Variable    0.03%
# 1           NaN            Offline            NaN      Variable    0.03%
# 2           NaN            Offline            NaN      Variable    0.04%
# 3           NaN            Offline            NaN      Variable    0.04%
# 4           NaN            Offline            NaN      Variable    0.05%
#
#      APY
# 0  0.03%
# 1  0.03%
# 2  0.04%
# 3  0.04%
# 4  0.05%

# %%
for idx in range(len(df_deposit.index)):
    if "Below" in str(df_deposit['Balance'].iloc[idx]) or "or less" in str(df_deposit['Balance'].iloc[idx]) or "Less than" in str(df_deposit['Balance'].iloc[idx]) or "less than" in str(df_deposit['Balance'].iloc[idx]) or "Up to" in str(df_deposit['Balance'].iloc[idx]):
        df_deposit['Maxm_Balance'].iloc[idx] = df_deposit['Balance'].iloc[idx]
    elif "-" in str(df_deposit['Balance'].iloc[idx]):
        df_deposit['Minm_Balance'].iloc[idx], df_deposit['Maxm_Balance'].iloc[idx] = str(df_deposit['Balance'].iloc[idx]).split("-")
    elif " to " in str(df_deposit['Balance'].iloc[idx]):
        df_deposit['Minm_Balance'].iloc[idx], df_deposit['Maxm_Balance'].iloc[idx] = str(df_deposit['Balance'].iloc[idx]).split("to")
    else:
        df_deposit['Minm_Balance'].iloc[idx] = df_deposit['Balance'].iloc[idx]

# %%
df_deposit.drop(columns=['Balance'], inplace=True)

# %%
for idx in range(len(df_deposit.index)):
    text1 = str(df_deposit['Maxm_Balance'].iloc[idx])    
    result = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", text1)
    try:
        df_deposit['Maxm_Balance'].iloc[idx] = result[0]
    except IndexError:
        df_deposit['Maxm_Balance'].iloc[idx] = np.NAN
        
    text2 = str(df_deposit['Minm_Balance'].iloc[idx])    
    result = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", text2)
    try:
        df_deposit['Minm_Balance'].iloc[idx] = result[0]
    except IndexError:
        df_deposit['Minm_Balance'].iloc[idx] = np.NAN

# %%
df_deposit.to_csv(output_path+"US\\" + "US_Deposits_Data_{}.csv".format(now.strftime("%m_%d_%Y")), index=False )
